# %% [markdown]
# # Train YOLO Models in Google Colab
# **Author:** Evan Juras, [EJ Technology Consultants](https://ejtech.io)
#
# **Last updated:** January 3, 2025 LOJAIYNNE
#
# **GitHub:** [Train and Deploy YOLO Models](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models)
#
# # Introduction
#
# This notebook uses [Ultralytics](https://docs.ultralytics.com/) to train YOLO11, YOLOv8, or YOLOv5 object detection models with a custom dataset. At the end of this Colab, you'll have a custom YOLO model that you can run on your PC, phone, or edge device like the Raspberry Pi.
#
# <p align=center>
# <img src="https://s3.us-west-1.amazonaws.com/evanjuras.com/img/yolo-model-demo.gif" height="360"><br>
# <i>Custom YOLO candy detection model in action!</i>
# </p>
#
# I created a YouTube video that walks through this guide step by step. I recommend following along with the video while working through this notebook.
#
# <p align=center>
# <a href="https://youtu.be/r0RspiLG260" target="_blank"><img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/Train_YOLO_Thumbnail2.png" height="240"><br>
# <i>Click here to go to the video!</i></a>
# </p>
#
# **Important note: This notebook will be continuously updated to make sure it works with newer versions of Ultralytics and YOLO. If you see any differences between the YouTube video and this notebook, always follow the notebook!**
#
# ### Working in Colab
# Colab provides a virtual machine in your browser complete with a Linux OS, filesystem, Python environment, and best of all, a free GPU. We'll install PyTorch and Ultralytics in this environment and use it to train our model. Simply click the Play button on sections of code in this notebook to execute them on the virtual machine.
#
# ### Navigation
# To navigate this notebook, use the table of contents in the left sidebar to jump from section to section.

# %% [markdown]
# **Verify NVIDIA GPU Availability**
#
# Make sure you're using a GPU-equipped machine by going to "Runtime" -> "Change runtime type" in the top menu bar, and then selecting one of the GPU options in the Hardware accelerator section. Click Play on the following code block to verify that the NVIDIA GPU is present and ready for training.

# %%
# !nvidia-smi
# Out:
# Tue Jan 27 17:02:29 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# #1.&nbsp;Gather and Label Training Images

# %% [markdown]
# Before we start training, we need to gather and label images that will be used for training the object detection model. A good starting point for a proof-of-concept model is 200 images. The training images should have random objects in the image along with the desired objects, and should have a variety of backgrounds and lighting conditions.
#
# There are a couple options for gathering images:
#
#
# *   Build a custom dataset by taking your own pictures of the objects and labeling them (this typically results in the best performance)
# *   Find a pre-made dataset from sources like [Roboflow Universe](), [Kaggle](), or [Google Images V7]()
#
#
# If you want to build your own dataset, there are several tools available for labeling images. One good option is [Label Studio](https://labelstud.io/?utm_source=youtube&utm_medium=video&utm_campaign=edjeelectronics), a free and open-source labeling tool that has a simple workflow while providing capabilities for more advanced features. My YouTube video that walks through this notebook (link to be added soon) shows how to label images with Label Studio.
#
# <p align=center>
# <img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/label-studio-example.PNG" height="380"><br>
# <i>Example of a candy image labeled with Label Studio.</i>
# </p>
#
# If you used Label Studio to label and export the images, they'll be exported in a `project.zip` file that contains the following:
#
# - An `images` folder containing the images
# - A `labels` folder containing the labels in YOLO annotation format
# - A `classes.txt` labelmap file that contains all the classes
# - A `notes.json` file that contains info specific to Label Studio (this file can be ignored)
#
# If you obtained your dataset from another source (like Roboflow Universe) or used another tool to label your dataset, make sure the files are organized in the same folder structure.
#
# <p align=center>
# <img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/zipped-data-example.png" height=""><br>
# <i>Organize your data in the folders shown here. See my <a href="https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/candy_data_06JAN25.zip">Candy Detection Dataset</a> for an example.</i>
# </p>
#
# Once you've got your dataset built, put into the file structure shown above, and zipped into `data.zip`, you're ready to move on to the next step.

# %% [markdown]
# # 2.&nbsp;Upload Image Dataset and Prepare Training Data

# %% [markdown]
# Next, we'll upload our dataset and prepare it for training with YOLO. We'll split the dataset into train and validation folders, and we'll automatically generate the configuration file for training the model.

# %% [markdown]
# ## 2.1 Upload images
#
# First, we need to upload the dataset to Colab. Here are a few options for moving the `data.zip` folder into this Colab instance.

# %% [markdown]
# **Option 1. Upload through Google Colab**
#
# Upload the `data.zip` file to the Google Colab instance by clicking the "Files" icon on the left hand side of the browser, and then the "Upload to session storage" icon. Select the zip folder to upload it.
#
# <p>
# <br>
# <img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/upload-colab-files.png" height="240">
# </p>

# %% [markdown]
# **Option 2. Copy from Google Drive**
#
# You can also upload your images to your personal Google Drive, mount the drive on this Colab session, and copy them over to the Colab filesystem. This option works well if you want to upload the images beforehand so you don't have to wait for them to upload each time you restart this Colab. If you have more than 50MB worth of images, I recommend using this option.
#
# First, upload the `data.zip` file to your Google Drive, and make note of the folder you uploaded them to. Replace `MyDrive/path/to/data.zip` with the path to your zip file. (For example, I uploaded the zip file to folder called "candy-dataset1", so I would use `MyDrive/candy-dataset1/data.zip` for the path). Then, run the following block of code to mount your Google Drive to this Colab session and copy the folder to this filesystem.

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# !cp /content/gdrive/MyDrive/path/to/data.zip /content

# %% [markdown]
# **Option 3. Use my candy detection or coin detection dataset**
#
# If you just want to test the process on a pre-made dataset, you can use one of my datasets:
#
# *   [Candy image dataset](https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/candy_data_14DEC24.zip), which contains 162 pictures of popular candies (Skittles, Snickers, etc)
# *   [Coin image dataset](https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/YOLO_coin_data_12DEC30.zip), which contains 750 pictures of US coins (pennies, dimes, nickels, and quarters)
#
# Download one of the datasets by running the following code block. I'll use the candy detection dataset as the example for the rest of the notebook.

# %%
# To use my one of pre-made dataset instead of your own custom dataset, download it here (control which dataset is downloaded by commenting out either line)
# !wget -O /content/data.zip https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/candy_data_06JAN25.zip # Candy dataset
#!wget -O /content/data.zip https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/YOLO_coin_data_12DEC30.zip # Coin dataset

# %% [markdown]
# ## 2.2 Split images into train and validation folders

# %% [markdown]
# At this point, whether you used Option 1, 2, or 3, you should be able to click the folder icon on the left and see your `data.zip` file in the list of files. Next, we'll unzip `data.zip` and create some folders to hold the images. Run the following code block to unzip the data.

# %%
# Unzip images to a custom data folder
# !unzip -q /content/data.zip -d /content/custom_data

# %% [markdown]
# Ultralytics requires a particular folder structure to store training data for models. Ultralytics requires a particular folder structure to store training data for models. The root folder is named “data”. Inside, there are two main folders:
#
# *   **Train**: These are the actual images used to train the model. In one epoch of training, every image in the train set is passed into the neural network. The training algorithm adjusts the network weights to fit the data in the images.
#
#
# *   **Validation**: These images are used to check the model's performance at the end of each training epoch.
#
# In each of these folders is a “images” folder and a “labels” folder, which hold the image files and annotation files respectively.

# %% [markdown]
# I wrote a Python script that will automatically create the required folder structure and randomly move 90% of dataset to the "train" folder and 10% to the "validation" folder. Run the following code block to download and execute the scrpt.

# %%
# !wget -O /content/train_val_split.py https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/utils/train_val_split.py

# TO DO: Improve robustness of train_val_split.py script so it can handle nested data folders, etc
# !python train_val_split.py --datapath="/content/custom_data" --train_pct=0.9
# Out:
# --2026-01-27 17:02:59--  https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/utils/train_val_split.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3203 (3.1K) [text/plain]
# Saving to: ‘/content/train_val_split.py’
#
# /content/train_val_ 100%[===================>]   3.13K  --.-KB/s    in 0s
#
# 2026-01-27 17:02:59 (60.1 MB/s) - ‘/content/train_val_split.py’ saved [3203/3203]
#
# Created folder at /content/data/train/images.
# Created folder at /content/data/train/labels.
# Created folder at /content/data/validation/images.
# Created folder at /content/data/validation/labels.
# Number of image files: 1740
# Number of annotation files: 1740
# Images moving to train: 1566
# Images moving to validation: 174

# %% [markdown]
# # 3.&nbsp;Install Requirements (Ultralytics)
#
# Next, we'll install the Ultralytics library in this Google Colab instance. This Python library will be used to train the YOLO model.

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.8-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch<2.10,>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.24.0+cu126)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.31.0)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<2.10,>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<2.10,>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.8-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 33.5 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.4.8 ultralytics-thop-2.0.18

# %% [markdown]
# # 4.&nbsp;Configure Training

# %% [markdown]
# There's one last step before we can run training: we need to create the Ultralytics training configuration YAML file. This file specifies the location of your train and validation data, and it also defines the model's classes. An example configuration file model is available [here](https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/datasets/coco128.yaml).
#
# Run the code block below to automatically generate a `data.yaml` configuration file. Make sure you have a labelmap file located at `custom_data/classes.txt`. If you used Label Studio or one of my pre-made datasets, it should already be present. If you assembled the dataset another way, you may have to manually create the `classes.txt` file (see [here](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/blob/main/doc/classes.txt) for an example of how it's formatted).

# %%
# Python function to automatically create data.yaml config file
# 1. Reads "classes.txt" file to get list of class names
# 2. Creates data dictionary with correct paths to folders, number of classes, and names of classes
# 3. Writes data in YAML format to data.yaml

import yaml
import os

def create_data_yaml(path_to_classes_txt, path_to_data_yaml):

  # Read class.txt to get class names
  if not os.path.exists(path_to_classes_txt):
    print(f'classes.txt file not found! Please create a classes.txt labelmap and move it to {path_to_classes_txt}')
    return
  with open(path_to_classes_txt, 'r') as f:
    classes = []
    for line in f.readlines():
      if len(line.strip()) == 0: continue
      classes.append(line.strip())
  number_of_classes = len(classes)

  # Create data dictionary
  data = {
      'path': '/content/data',
      'train': 'train/images',
      'val': 'validation/images',
      'nc': number_of_classes,
      'names': classes
  }

  # Write data to YAML file
  with open(path_to_data_yaml, 'w') as f:
    yaml.dump(data, f, sort_keys=False)
  print(f'Created config file at {path_to_data_yaml}')

  return

# Define path to classes.txt and run function
path_to_classes_txt = '/content/custom_data/classes.txt'
path_to_data_yaml = '/content/data.yaml'

create_data_yaml(path_to_classes_txt, path_to_data_yaml)

print('\nFile contents:\n')
# !cat /content/data.yaml
# Out:
# Created config file at /content/data.yaml
#
# File contents:
#
# path: /content/data
# train: train/images
# val: validation/images
# nc: 3
# names:
# - metal
# - paper
# - plastic

# %% [markdown]
# # 5.&nbsp;Train Model

# %% [markdown]
# ## 5.1 Training Parameters
# Now that the data is organized and the config file is created, we're ready to start training! First, there are a few important parameters to decide on. Visit my article on [Training YOLO Models Locally](https://www.ejtech.io/learn/train-yolo-models) to learn more about these parameters and how to choose them.
#
# **Model architecture & size (`model`):**
#
# There are several YOLO11 models sizes available to train, including `yolo11n.pt`, `yolo11s.pt`, `yolo11m.pt`, `yolo11l.pt`, and `yolo11xl.pt`. Larger models run slower but have higher accuracy, while smaller models run faster but have lower accuracy. I made a brief YouTube video that compares performance of different YOLO models on a Raspberry Pi 5 and a laptop with a RTX 4050 GPU, [check it out here to get a sense of their speed accuracy](https://youtu.be/_WKS4E9SmkA). If you aren't sure which model size to use, `yolo11s.pt` is a good starting point.
#
# You can also train YOLOv8 or YOLOv5 models by substituting `yolo11` for `yolov8` or `yolov5`.
#
#
# **Number of epochs (`epochs`)**
#
# In machine learning, one “epoch” is one single pass through the full training dataset. Setting the number of epochs dictates how long the model will train for. The best amount of epochs to use depends on the size of the dataset and the model architecture. If your dataset has less than 200 images, a good starting point is 60 epochs. If your dataset has more than 200 images, a good starting point is 40 epochs.
#
#
# **Resolution (`imgsz`)**
#
# Resolution has a large impact on the speed and accuracy of the model: a lower resolution model will have higher speed but less accuracy. YOLO models are typically trained and inferenced at a 640x640 resolution. However, if you want your model to run faster or know you will be working with low-resolution images, try using a lower resolution like 480x480.

# %% [markdown]
# ## 5.2 Run Training!

# %% [markdown]
# Run the following code block to begin training. If you want to use a different model, number of epochs, or resolution, change `model`, `epochs`, or `imgsz`.

# %%
# !yolo detect train data=/content/data.yaml model=yolov8s.pt epochs=80 imgsz=480
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8s.pt to 'yolov8s.pt': 100% ━━━━━━━━━━━━ 21.5MB 216.2MB/s 0.1s
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=80, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=480, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 27.9MB/s 0.0s
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2117209  ultralytics.nn.modules.head.Detect           [3, 16, None, [128, 256, 512]]
# Model summary: 130 layers, 11,136,761 parameters, 11,136,745 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 110.3MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1310.0±458.6 MB/s, size: 33.5 KB)
# train: Scanning /content/data/train/labels... 1566 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1566/1566 2.6Kit/s 0.6s
# train: New cache created: /content/data/train/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 278, len(boxes) = 2194. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 437.7±124.0 MB/s, size: 43.0 KB)
# val: Scanning /content/data/validation/labels... 174 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 174/174 2.2Kit/s 0.1s
# val: New cache created: /content/data/validation/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 28, len(boxes) = 234. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Plotting labels to /content/runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 480 train, 480 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/train
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/80      2.15G      1.116      1.863      1.397         66        480: 100% ━━━━━━━━━━━━ 98/98 4.3it/s 22.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.7it/s 2.2s
#                    all        174        234       0.66      0.535      0.573      0.358
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/80      2.83G      1.288      1.657      1.489         38        480: 100% ━━━━━━━━━━━━ 98/98 4.8it/s 20.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.6it/s 1.1s
#                    all        174        234       0.48      0.397      0.376      0.168
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/80      2.87G      1.351      1.729      1.545         38        480: 100% ━━━━━━━━━━━━ 98/98 5.1it/s 19.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.7it/s 1.3s
#                    all        174        234      0.208      0.271      0.113      0.048
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/80       2.9G      1.362      1.683      1.547         38        480: 100% ━━━━━━━━━━━━ 98/98 5.0it/s 19.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.5it/s 1.1s
#                    all        174        234      0.637      0.431      0.478      0.292
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/80      2.94G      1.295      1.618      1.505         42        480: 100% ━━━━━━━━━━━━ 98/98 4.9it/s 20.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.2it/s 1.2s
#                    all        174        234      0.544      0.541      0.518      0.311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/80      2.98G      1.255       1.53      1.476         32        480: 100% ━━━━━━━━━━━━ 98/98 5.1it/s 19.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.5it/s 1.1s
#                    all        174        234       0.68      0.525      0.594      0.382
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/80      3.01G      1.237      1.513       1.45         43        480: 100% ━━━━━━━━━━━━ 98/98 5.0it/s 19.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.5it/s 1.1s
#                    all        174        234      0.585       0.58      0.567      0.359
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/80      3.05G      1.172      1.397      1.405         36        480: 100% ━━━━━━━━━━━━ 98/98 4.9it/s 20.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.4it/s 1.1s
#                    all        174        234      0.783      0.625      0.711      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/80      3.09G      1.144        1.4      1.393         46        480: 100% ━━━━━━━━━━━━ 98/98 5.1it/s 19.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.6it/s 1.1s
#                    all        174        234      0.683       0.52       0.57       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/80      3.12G       1.12      1.285      1.376         30        480: 100% ━━━━━━━━━━━━ 98/98 4.9it/s 20.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.6it/s 1.1s
#                    all        174        234      0.779      0.595      0.715      0.499
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/80      3.16G      1.091      1.277      1.368         62        480: 100% ━━━━━━━━━━━━ 98/98 4.9it/s 20.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.6it/s 1.1s
#                    all        174        234      0.653      0.539      0.592      0.382
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/80      3.19G       1.08       1.22       1.36         38        480: 100% ━━━━━━━━━━━━ 98/98 5.1it/s 19.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.6it/s 1.1s
#                    all        174        234      0.792      0.663       0.72      0.505
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/80      3.23G      1.064      1.231      1.352         31        480: 100% ━━━━━━━━━━━━ 98/98 4.8it/s 20.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.8it/s 1.0s
#                    all        174        234      0.794      0.716      0.784      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/80      3.27G      1.052      1.141      1.329         33        480: 100% ━━━━━━━━━━━━ 98/98 4.9it/s 20.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.7it/s 1.0s
#                    all        174        234      0.755      0.622      0.702      0.504
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/80       3.3G      1.043      1.156      1.336         36        480: 100% ━━━━━━━━━━━━ 98/98 5.1it/s 19.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.3it/s 1.1s
#                    all        174        234      0.844       0.66      0.796      0.589
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/80      3.34G      1.022      1.105       1.31         39        480: 100% ━━━━━━━━━━━━ 98/98 4.9it/s 20.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.7it/s 1.0s
#                    all        174        234      0.798       0.68      0.753      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/80      3.38G     0.9863      1.047        1.3         30        480: 100% ━━━━━━━━━━━━ 98/98 4.9it/s 20.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.0it/s 1.2s
#                    all        174        234      0.797      0.652      0.725      0.539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/80      3.41G     0.9777       1.05      1.297         43        480: 100% ━━━━━━━━━━━━ 98/98 5.0it/s 19.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.7it/s 1.0s
#                    all        174        234      0.856      0.654      0.773      0.587
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/80      3.45G     0.9736      1.023      1.289         35        480: 100% ━━━━━━━━━━━━ 98/98 4.9it/s 20.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.7it/s 1.0s
#                    all        174        234      0.893      0.729      0.831      0.624
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/80      3.49G     0.9634      1.035      1.286         44        480: 100% ━━━━━━━━━━━━ 98/98 4.9it/s 19.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.0it/s 1.2s
#                    all        174        234      0.872      0.688      0.807        0.6
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/80      3.52G     0.9339     0.9765      1.262         38        480: 100% ━━━━━━━━━━━━ 98/98 5.1it/s 19.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.8it/s 1.0s
#                    all        174        234       0.84      0.766      0.828      0.618
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/80      3.56G      0.943     0.9472      1.261         33        480: 100% ━━━━━━━━━━━━ 98/98 4.8it/s 20.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.6it/s 1.1s
#                    all        174        234      0.771      0.686      0.758       0.57
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/80       3.6G     0.9399     0.9615      1.269         38        480: 100% ━━━━━━━━━━━━ 98/98 4.9it/s 19.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.1it/s 1.5s
#                    all        174        234      0.891      0.675      0.806      0.595
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/80      3.82G     0.9001     0.9049      1.238         37        480: 100% ━━━━━━━━━━━━ 98/98 5.1it/s 19.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.6it/s 1.1s
#                    all        174        234      0.944      0.745      0.862      0.653
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/80      3.86G      0.914     0.9063      1.244         51        480: 100% ━━━━━━━━━━━━ 98/98 4.8it/s 20.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.7it/s 1.0s
#                    all        174        234       0.89      0.709      0.835      0.638
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/80      3.89G      0.881     0.9169      1.249         42        480: 100% ━━━━━━━━━━━━ 98/98 5.0it/s 19.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.9it/s 1.5s
#                    all        174        234      0.863      0.731      0.825      0.626
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/80      3.93G     0.9009     0.9241      1.242         36        480: 100% ━━━━━━━━━━━━ 98/98 5.0it/s 19.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.5it/s 1.1s
#                    all        174        234      0.871      0.735      0.834      0.633
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/80      3.97G     0.8823     0.8853      1.233         41        480: 100% ━━━━━━━━━━━━ 98/98 4.8it/s 20.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.6it/s 1.1s
#                    all        174        234      0.856      0.736      0.821      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/80         4G     0.8791     0.8801      1.231         43        480: 100% ━━━━━━━━━━━━ 98/98 4.9it/s 20.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.4it/s 1.7s
#                    all        174        234      0.916       0.71      0.827      0.651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/80      4.04G     0.8558     0.8269      1.207         33        480: 100% ━━━━━━━━━━━━ 98/98 5.0it/s 19.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.6it/s 1.1s
#                    all        174        234      0.856      0.793      0.859      0.663
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/80      4.08G     0.8538     0.8216      1.208         36        480: 100% ━━━━━━━━━━━━ 98/98 4.8it/s 20.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.5it/s 1.1s
#                    all        174        234      0.865      0.805      0.868      0.682
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/80      4.11G     0.8671     0.8407      1.212         49        480: 100% ━━━━━━━━━━━━ 98/98 4.8it/s 20.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.0it/s 1.2s
#                    all        174        234       0.85      0.742      0.832      0.648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/80      4.15G     0.8234     0.7912       1.19         38        480: 100% ━━━━━━━━━━━━ 98/98 5.0it/s 19.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.5it/s 1.1s
#                    all        174        234      0.869      0.762      0.854      0.662
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/80      4.19G     0.8331     0.7944      1.203         40        480: 100% ━━━━━━━━━━━━ 98/98 4.8it/s 20.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.6it/s 1.1s
#                    all        174        234      0.867      0.816      0.884        0.7
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/80      4.22G     0.8183     0.7803       1.19         36        480: 100% ━━━━━━━━━━━━ 98/98 4.8it/s 20.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.5it/s 1.1s
#                    all        174        234      0.959      0.776      0.898      0.705
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/80      4.59G     0.8072     0.7532      1.184         52        480: 100% ━━━━━━━━━━━━ 98/98 5.1it/s 19.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.6it/s 1.1s
#                    all        174        234      0.873      0.795      0.864      0.689
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/80      4.63G     0.8226     0.7827      1.203         34        480: 100% ━━━━━━━━━━━━ 98/98 4.8it/s 20.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.5it/s 1.1s
#                    all        174        234      0.875      0.772      0.859      0.682
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/80      4.66G     0.8204     0.7692      1.186         34        480: 100% ━━━━━━━━━━━━ 98/98 4.8it/s 20.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.5it/s 1.1s
#                    all        174        234      0.917        0.8      0.878      0.695
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/80       4.7G     0.7943     0.7393      1.178         37        480: 100% ━━━━━━━━━━━━ 98/98 5.1it/s 19.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.5it/s 1.1s
#                    all        174        234      0.912      0.769      0.876      0.709
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/80      4.74G     0.8031     0.7297      1.174         30        480: 100% ━━━━━━━━━━━━ 98/98 4.8it/s 20.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.7it/s 1.1s
#                    all        174        234      0.858      0.812      0.891      0.698
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/80      4.77G     0.7912     0.7306      1.175         31        480: 100% ━━━━━━━━━━━━ 98/98 4.9it/s 19.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s
#                    all        174        234      0.897      0.819      0.893      0.698
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/80      4.81G     0.7575     0.7017      1.154         62        480: 100% ━━━━━━━━━━━━ 98/98 5.1it/s 19.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.7it/s 1.1s
#                    all        174        234      0.873       0.83      0.891      0.714
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/80      4.85G      0.771     0.6929      1.152         34        480: 100% ━━━━━━━━━━━━ 98/98 4.8it/s 20.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.7it/s 1.0s
#                    all        174        234      0.913      0.778      0.881      0.705
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/80      4.88G     0.7773     0.7023      1.162         40        480: 100% ━━━━━━━━━━━━ 98/98 4.9it/s 20.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.6it/s 1.3s
#                    all        174        234      0.944      0.833      0.913      0.731
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/80      4.92G     0.7781     0.6997      1.156         35        480: 100% ━━━━━━━━━━━━ 98/98 5.1it/s 19.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.8it/s 1.0s
#                    all        174        234      0.905      0.829      0.889      0.728
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/80      4.95G     0.7583     0.6721      1.145         39        480: 100% ━━━━━━━━━━━━ 98/98 4.8it/s 20.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.8it/s 1.0s
#                    all        174        234       0.95      0.803      0.907      0.726
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/80      4.99G     0.7441     0.6519      1.133         38        480: 100% ━━━━━━━━━━━━ 98/98 5.0it/s 19.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.8it/s 1.6s
#                    all        174        234      0.921      0.795      0.885      0.716
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/80      5.05G     0.7636     0.6662       1.15         27        480: 100% ━━━━━━━━━━━━ 98/98 5.0it/s 19.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.3it/s 1.1s
#                    all        174        234      0.928      0.813      0.904      0.721
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/80      5.12G     0.7462     0.6463      1.127         48        480: 100% ━━━━━━━━━━━━ 98/98 4.8it/s 20.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.3it/s 1.1s
#                    all        174        234      0.923      0.839      0.901      0.734
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/80      5.18G      0.718     0.6314      1.121         30        480: 100% ━━━━━━━━━━━━ 98/98 4.8it/s 20.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.9it/s 1.2s
#                    all        174        234      0.901      0.804      0.883       0.72
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/80      5.25G     0.7195     0.6299      1.135         43        480: 100% ━━━━━━━━━━━━ 98/98 5.0it/s 19.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.5it/s 1.1s
#                    all        174        234      0.948      0.809      0.896      0.727
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/80      5.31G     0.7053      0.615      1.113         37        480: 100% ━━━━━━━━━━━━ 98/98 4.8it/s 20.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.4it/s 1.1s
#                    all        174        234      0.901      0.829      0.884      0.716
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/80      5.38G     0.7016     0.6125      1.125         40        480: 100% ━━━━━━━━━━━━ 98/98 4.8it/s 20.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.0it/s 1.2s
#                    all        174        234      0.905      0.847      0.898      0.731
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/80      5.44G     0.7135      0.611      1.122         35        480: 100% ━━━━━━━━━━━━ 98/98 5.1it/s 19.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.7it/s 1.1s
#                    all        174        234      0.908      0.842      0.914      0.746
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/80      5.52G     0.7014      0.604       1.12         43        480: 100% ━━━━━━━━━━━━ 98/98 4.8it/s 20.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.7it/s 1.0s
#                    all        174        234      0.921      0.843      0.906      0.753
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/80      5.57G     0.6905     0.5857      1.114         38        480: 100% ━━━━━━━━━━━━ 98/98 4.9it/s 20.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.5it/s 1.1s
#                    all        174        234      0.947      0.801      0.909      0.754
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/80      5.65G     0.7064     0.5934      1.115         46        480: 100% ━━━━━━━━━━━━ 98/98 5.0it/s 19.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.4it/s 1.1s
#                    all        174        234      0.913      0.801      0.894       0.74
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/80       5.7G      0.693     0.5888      1.114         37        480: 100% ━━━━━━━━━━━━ 98/98 4.8it/s 20.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.7it/s 1.1s
#                    all        174        234      0.924      0.827      0.901      0.732
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       59/80      5.78G     0.6693     0.5729        1.1         38        480: 100% ━━━━━━━━━━━━ 98/98 4.9it/s 20.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.3it/s 1.1s
#                    all        174        234      0.953      0.791      0.897      0.745
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       60/80      5.83G     0.6753     0.5837      1.103         42        480: 100% ━━━━━━━━━━━━ 98/98 5.0it/s 19.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.2it/s 1.2s
#                    all        174        234      0.943      0.831      0.914      0.763
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       61/80      5.91G     0.6813     0.5674      1.102         31        480: 100% ━━━━━━━━━━━━ 98/98 4.8it/s 20.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.5it/s 1.1s
#                    all        174        234      0.906      0.816        0.9      0.748
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       62/80      5.96G     0.6699     0.5719      1.098         35        480: 100% ━━━━━━━━━━━━ 98/98 4.8it/s 20.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.6it/s 1.1s
#                    all        174        234      0.967      0.812      0.913      0.754
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       63/80      6.02G     0.6637     0.5498      1.094         46        480: 100% ━━━━━━━━━━━━ 98/98 5.0it/s 19.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.7it/s 1.0s
#                    all        174        234      0.957       0.84      0.916      0.753
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       64/80      6.09G     0.6494     0.5411       1.09         39        480: 100% ━━━━━━━━━━━━ 98/98 4.8it/s 20.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.7it/s 1.1s
#                    all        174        234      0.943      0.845       0.91      0.765
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       65/80      6.15G     0.6537     0.5429      1.083         35        480: 100% ━━━━━━━━━━━━ 98/98 4.8it/s 20.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.6it/s 1.1s
#                    all        174        234      0.959      0.814      0.911      0.755
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       66/80      6.21G     0.6249      0.515      1.076         47        480: 100% ━━━━━━━━━━━━ 98/98 5.0it/s 19.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.7it/s 1.1s
#                    all        174        234      0.966      0.813      0.908      0.757
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       67/80       6.3G     0.6414     0.5282      1.083         47        480: 100% ━━━━━━━━━━━━ 98/98 4.8it/s 20.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.3it/s 1.1s
#                    all        174        234      0.952      0.824      0.914      0.757
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       68/80      6.34G     0.6143     0.5171      1.069         43        480: 100% ━━━━━━━━━━━━ 98/98 4.8it/s 20.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.5it/s 1.1s
#                    all        174        234      0.944      0.832      0.921      0.766
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       69/80      6.41G      0.624     0.5128       1.08         33        480: 100% ━━━━━━━━━━━━ 98/98 5.1it/s 19.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.2it/s 1.1s
#                    all        174        234      0.934      0.813      0.917      0.765
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       70/80      6.47G     0.6192     0.4981      1.069         36        480: 100% ━━━━━━━━━━━━ 98/98 4.8it/s 20.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.7it/s 1.0s
#                    all        174        234      0.945      0.828      0.911      0.759
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       71/80      6.54G     0.5548     0.4114      1.029         17        480: 100% ━━━━━━━━━━━━ 98/98 4.6it/s 21.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.6it/s 1.1s
#                    all        174        234      0.921      0.845      0.924      0.761
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       72/80       6.6G     0.5353     0.3694      1.003         17        480: 100% ━━━━━━━━━━━━ 98/98 5.1it/s 19.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.4it/s 1.1s
#                    all        174        234      0.954      0.811      0.917      0.767
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       73/80      6.68G     0.5166     0.3585     0.9939         17        480: 100% ━━━━━━━━━━━━ 98/98 4.5it/s 21.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.7it/s 1.1s
#                    all        174        234       0.96      0.817      0.927      0.776
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       74/80      6.73G      0.499     0.3469     0.9894         14        480: 100% ━━━━━━━━━━━━ 98/98 4.9it/s 19.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.6it/s 1.1s
#                    all        174        234      0.906      0.861      0.923      0.778
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       75/80      6.87G     0.5024     0.3357     0.9902         25        480: 100% ━━━━━━━━━━━━ 98/98 5.2it/s 18.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.7it/s 1.1s
#                    all        174        234      0.909      0.848      0.922      0.775
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       76/80      6.91G     0.4951     0.3377     0.9971         23        480: 100% ━━━━━━━━━━━━ 98/98 5.0it/s 19.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.5it/s 1.1s
#                    all        174        234      0.955      0.828      0.926      0.781
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       77/80      6.94G     0.4933     0.3309     0.9893         19        480: 100% ━━━━━━━━━━━━ 98/98 5.1it/s 19.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.0it/s 1.5s
#                    all        174        234      0.949      0.824       0.92       0.78
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       78/80         7G     0.4792      0.335     0.9811         19        480: 100% ━━━━━━━━━━━━ 98/98 5.2it/s 18.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.6it/s 1.1s
#                    all        174        234      0.964      0.825      0.925      0.782
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       79/80      7.07G     0.4738     0.3204     0.9719         15        480: 100% ━━━━━━━━━━━━ 98/98 5.0it/s 19.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.4it/s 1.1s
#                    all        174        234      0.968      0.813      0.922      0.787
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       80/80      7.13G     0.4672     0.3068     0.9669         16        480: 100% ━━━━━━━━━━━━ 98/98 5.2it/s 18.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 5.6it/s 1.1s
#                    all        174        234      0.918      0.856      0.922      0.787
#
# 80 epochs completed in 0.478 hours.
# Optimizer stripped from /content/runs/detect/train/weights/last.pt, 22.5MB
# Optimizer stripped from /content/runs/detect/train/weights/best.pt, 22.5MB
#
# Validating /content/runs/detect/train/weights/best.pt...
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 73 layers, 11,126,745 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.6it/s 2.3s
#                    all        174        234      0.918      0.855      0.922      0.787
#                  metal         67         89      0.944      0.953      0.979      0.898
#                  paper         50         58       0.86      0.739      0.835      0.663
#                plastic         57         87      0.951      0.874      0.953      0.801
# Speed: 0.4ms preprocess, 3.6ms inference, 0.0ms loss, 3.1ms postprocess per image
# Results saved to /content/runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# The training algorithm will parse the images in the training and validation directories and then start training the model. At the end of each training epoch, the program runs the model on the validation dataset and reports the resulting mAP, precision, and recall. As training continues, the mAP should generally increase with each epoch. Training will end once it goes through the number of epochs specified by `epochs`.
#
# > **NOTE:** Make sure to allow training to run to completion, because an optimizer runs at the end of training that strips out unneeded layers from the model.
#
# The best trained model weights will be saved in `content/runs/detect/train/weights/best.pt`. Additional information about training is saved in the `content/runs/detect/train` folder, including a `results.png` file that shows how loss, precision, recall, and mAP progressed over each epoch.

# %% [markdown]
# #6.&nbsp;Test Model

# %% [markdown]
# The model has been trained; now it's time to test it! The commands below run the model on the images in the validation folder and then display the results for the first 10 images. This is a good way to confirm your model is working as expected. Click Play on the blocks below to see how your model performs.

# %%
# !yolo detect predict model=runs/detect/train/weights/best.pt source=data/validation/images save=True
# Out:
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 73 layers, 11,126,745 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/174 /content/data/validation/images/metal_can1.jpg: 480x480 5 metals, 10.7ms
# image 2/174 /content/data/validation/images/metal_can104.jpg: 480x480 1 metal, 10.7ms
# image 3/174 /content/data/validation/images/metal_can105.jpg: 480x480 1 metal, 10.6ms
# image 4/174 /content/data/validation/images/metal_can107.jpg: 480x480 1 metal, 10.6ms
# image 5/174 /content/data/validation/images/metal_can112.jpg: 480x480 1 metal, 10.6ms
# image 6/174 /content/data/validation/images/metal_can121.jpg: 480x480 1 metal, 10.6ms
# image 7/174 /content/data/validation/images/metal_can126.jpg: 480x480 1 metal, 10.6ms
# image 8/174 /content/data/validation/images/metal_can141.jpg: 480x480 1 metal, 10.7ms
# image 9/174 /content/data/validation/images/metal_can144.jpg: 480x480 1 metal, 10.6ms
# image 10/174 /content/data/validation/images/metal_can148.jpg: 480x480 1 metal, 10.6ms
# image 11/174 /content/data/validation/images/metal_can151.jpg: 480x480 1 metal, 10.6ms
# image 12/174 /content/data/validation/images/metal_can160.jpg: 480x480 1 metal, 10.6ms
# image 13/174 /content/data/validation/images/metal_can162.jpg: 480x480 1 metal, 10.6ms
# image 14/174 /content/data/validation/images/metal_can188.jpg: 480x480 (no detections), 10.6ms
# image 15/174 /content/data/validation/images/metal_can19.jpg: 480x480 1 metal, 9.4ms
# image 16/174 /content/data/validation/images/metal_can193.jpg: 480x480 1 metal, 7.3ms
# image 17/174 /content/data/validation/images/metal_can20.jpg: 480x480 1 metal, 7.3ms
# image 18/174 /content/data/validation/images/metal_can22.jpg: 480x480 1 metal, 7.3ms
# image 19/174 /content/data/validation/images/metal_can24.jpg: 480x480 1 metal, 7.3ms
# image 20/174 /content/data/validation/images/metal_can33.jpg: 480x480 1 metal, 7.3ms
# image 21/174 /content/data/validation/images/metal_can53.jpg: 480x480 1 metal, 7.3ms
# image 22/174 /content/data/validation/images/metal_can55.jpg: 480x480 1 metal, 7.3ms
# image 23/174 /content/data/validation/images/metal_can58.jpg: 480x480 1 metal, 7.3ms
# image 24/174 /content/data/validation/images/metal_can78.jpg: 480x480 1 metal, 3 papers, 7.3ms
# image 25/174 /content/data/validation/images/metal_can88.jpg: 480x480 1 metal, 7.3ms
# image 26/174 /content/data/validation/images/metal_can99.jpg: 480x480 2 metals, 7.3ms
# image 27/174 /content/data/validation/images/metal_cutlery1.jpg: 384x480 1 metal, 42.6ms
# image 28/174 /content/data/validation/images/metal_cutlery101.jpg: 384x480 3 metals, 6.3ms
# image 29/174 /content/data/validation/images/metal_cutlery105.jpg: 384x480 3 metals, 6.3ms
# image 30/174 /content/data/validation/images/metal_cutlery120.jpg: 384x480 1 metal, 6.4ms
# image 31/174 /content/data/validation/images/metal_cutlery121.jpg: 384x480 1 metal, 6.4ms
# image 32/174 /content/data/validation/images/metal_cutlery123.jpg: 384x480 1 metal, 6.4ms
# image 33/174 /content/data/validation/images/metal_cutlery132.jpg: 384x480 4 metals, 6.3ms
# image 34/174 /content/data/validation/images/metal_cutlery136.jpg: 384x480 4 metals, 6.3ms
# image 35/174 /content/data/validation/images/metal_cutlery152.jpg: 384x480 2 metals, 6.2ms
# image 36/174 /content/data/validation/images/metal_cutlery156.jpg: 384x480 3 metals, 6.2ms
# image 37/174 /content/data/validation/images/metal_cutlery159.jpg: 384x480 2 metals, 6.2ms
# image 38/174 /content/data/validation/images/metal_cutlery164.jpg: 384x480 4 metals, 6.2ms
# image 39/174 /content/data/validation/images/metal_cutlery176.jpg: 384x480 1 metal, 6.2ms
# image 40/174 /content/data/validation/images/metal_cutlery180.jpg: 384x480 5 metals, 6.2ms
# image 41/174 /content/data/validation/images/metal_cutlery186.jpg: 384x480 3 metals, 6.2ms
# image 42/174 /content/data/validation/images/metal_cutlery197.jpg: 384x480 1 metal, 5.6ms
# image 43/174 /content/data/validation/images/metal_cutlery199.jpg: 384x480 1 metal, 5.5ms
# image 44/174 /content/data/validation/images/metal_cutlery32.jpg: 384x480 1 metal, 5.6ms
# image 45/174 /content/data/validation/images/metal_cutlery37.jpg: 384x480 1 metal, 5.6ms
# image 46/174 /content/data/validation/images/metal_cutlery50.jpg: 384x480 1 metal, 5.7ms
# image 47/174 /content/data/validation/images/metal_cutlery51.jpg: 384x480 1 metal, 5.5ms
# image 48/174 /content/data/validation/images/metal_cutlery62.jpg: 384x480 1 metal, 5.5ms
# image 49/174 /content/data/validation/images/metal_cutlery66.jpg: 384x480 1 metal, 5.5ms
# image 50/174 /content/data/validation/images/metal_cutlery73.jpg: 384x480 1 metal, 5.5ms
# image 51/174 /content/data/validation/images/metal_cutlery79.jpg: 384x480 1 metal, 5.4ms
# image 52/174 /content/data/validation/images/metal_cutlery83.jpg: 384x480 1 metal, 5.4ms
# image 53/174 /content/data/validation/images/metal_cutlery86.jpg: 384x480 1 metal, 5.4ms
# image 54/174 /content/data/validation/images/metal_screw118.jpg: 480x480 1 metal, 6.5ms
# image 55/174 /content/data/validation/images/metal_screw140.jpg: 480x480 1 metal, 5.6ms
# image 56/174 /content/data/validation/images/metal_screw144.jpg: 480x480 1 metal, 5.7ms
# image 57/174 /content/data/validation/images/metal_screw15.jpg: 480x480 1 metal, 5.6ms
# image 58/174 /content/data/validation/images/metal_screw168.jpg: 480x480 1 metal, 5.7ms
# image 59/174 /content/data/validation/images/metal_screw170.jpg: 480x480 1 metal, 5.4ms
# image 60/174 /content/data/validation/images/metal_screw171.jpg: 480x480 2 metals, 5.4ms
# image 61/174 /content/data/validation/images/metal_screw173.jpg: 480x480 1 metal, 5.7ms
# image 62/174 /content/data/validation/images/metal_screw178.jpg: 480x480 1 metal, 5.3ms
# image 63/174 /content/data/validation/images/metal_screw192.jpg: 480x480 1 metal, 5.4ms
# image 64/174 /content/data/validation/images/metal_screw34.jpg: 480x480 1 metal, 7.0ms
# image 65/174 /content/data/validation/images/metal_screw62.jpg: 480x480 1 metal, 7.5ms
# image 66/174 /content/data/validation/images/metal_screw83.jpg: 480x480 1 metal, 6.2ms
# image 67/174 /content/data/validation/images/metal_screw87.jpg: 480x480 1 metal, 5.3ms
# image 68/174 /content/data/validation/images/paper_cardboard125.jpg: 480x480 5 plastics, 5.4ms
# image 69/174 /content/data/validation/images/paper_cardboard135.jpg: 480x480 1 plastic, 5.4ms
# image 70/174 /content/data/validation/images/paper_cardboard138.jpg: 480x480 2 metals, 1 plastic, 9.1ms
# image 71/174 /content/data/validation/images/paper_cardboard140.jpg: 480x480 5 plastics, 8.7ms
# image 72/174 /content/data/validation/images/paper_cardboard149.jpg: 480x480 9 plastics, 5.9ms
# image 73/174 /content/data/validation/images/paper_cardboard164.jpg: 480x480 1 plastic, 5.5ms
# image 74/174 /content/data/validation/images/paper_cardboard182.jpg: 480x480 1 plastic, 5.4ms
# image 75/174 /content/data/validation/images/paper_cardboard184.jpg: 480x480 2 plastics, 5.3ms
# image 76/174 /content/data/validation/images/paper_cardboard198.jpg: 480x480 1 plastic, 5.7ms
# image 77/174 /content/data/validation/images/paper_cardboard200.jpg: 480x480 1 plastic, 5.6ms
# image 78/174 /content/data/validation/images/paper_cardboard32.jpg: 480x480 1 plastic, 5.4ms
# image 79/174 /content/data/validation/images/paper_cardboard35.jpg: 480x480 1 plastic, 5.6ms
# image 80/174 /content/data/validation/images/paper_cardboard37.jpg: 480x480 2 plastics, 5.5ms
# image 81/174 /content/data/validation/images/paper_cardboard38.jpg: 480x480 1 plastic, 5.8ms
# image 82/174 /content/data/validation/images/paper_cardboard48.jpg: 480x480 2 plastics, 5.6ms
# image 83/174 /content/data/validation/images/paper_cardboard56.jpg: 480x480 1 plastic, 5.4ms
# image 84/174 /content/data/validation/images/paper_cardboard81.jpg: 480x480 1 plastic, 5.2ms
# image 85/174 /content/data/validation/images/paper_cardboard83.jpg: 480x480 13 plastics, 5.2ms
# image 86/174 /content/data/validation/images/paper_newspaper105.jpg: 480x480 1 plastic, 5.3ms
# image 87/174 /content/data/validation/images/paper_newspaper120.jpg: 480x480 1 plastic, 5.3ms
# image 88/174 /content/data/validation/images/paper_newspaper139.jpg: 480x480 1 plastic, 5.4ms
# image 89/174 /content/data/validation/images/paper_newspaper143.jpg: 480x480 1 plastic, 5.3ms
# image 90/174 /content/data/validation/images/paper_newspaper169.jpg: 480x480 1 plastic, 5.3ms
# image 91/174 /content/data/validation/images/paper_newspaper18.jpg: 480x480 1 plastic, 5.3ms
# image 92/174 /content/data/validation/images/paper_newspaper190.jpg: 480x480 1 plastic, 5.2ms
# image 93/174 /content/data/validation/images/paper_newspaper193.jpg: 480x480 1 plastic, 5.3ms
# image 94/174 /content/data/validation/images/paper_newspaper21.jpg: 480x480 1 plastic, 5.2ms
# image 95/174 /content/data/validation/images/paper_newspaper28.jpg: 480x480 1 plastic, 5.3ms
# image 96/174 /content/data/validation/images/paper_newspaper39.jpg: 480x480 3 plastics, 5.7ms
# image 97/174 /content/data/validation/images/paper_newspaper43.jpg: 480x480 1 plastic, 5.3ms
# image 98/174 /content/data/validation/images/paper_newspaper53.jpg: 480x480 1 plastic, 5.4ms
# image 99/174 /content/data/validation/images/paper_newspaper55.jpg: 480x480 1 plastic, 5.3ms
# image 100/174 /content/data/validation/images/paper_newspaper60.jpg: 480x480 1 plastic, 5.3ms
# image 101/174 /content/data/validation/images/paper_newspaper62.jpg: 480x480 1 plastic, 5.3ms
# image 102/174 /content/data/validation/images/paper_newspaper70.jpg: 480x480 1 plastic, 6.2ms
# image 103/174 /content/data/validation/images/paper_newspaper92.jpg: 480x480 1 plastic, 7.0ms
# image 104/174 /content/data/validation/images/paper_newspaper95.jpg: 480x480 1 plastic, 5.3ms
# image 105/174 /content/data/validation/images/paper_tissue103.jpg: 384x480 1 plastic, 6.0ms
# image 106/174 /content/data/validation/images/paper_tissue119.jpg: 384x480 1 plastic, 5.4ms
# image 107/174 /content/data/validation/images/paper_tissue137.jpg: 384x480 1 plastic, 5.3ms
# image 108/174 /content/data/validation/images/paper_tissue138.jpg: 384x480 1 plastic, 5.3ms
# image 109/174 /content/data/validation/images/paper_tissue147.jpg: 384x480 (no detections), 5.5ms
# image 110/174 /content/data/validation/images/paper_tissue15.jpg: 384x480 1 plastic, 5.3ms
# image 111/174 /content/data/validation/images/paper_tissue150.jpg: 384x480 1 plastic, 5.4ms
# image 112/174 /content/data/validation/images/paper_tissue173.jpg: 384x480 1 plastic, 5.5ms
# image 113/174 /content/data/validation/images/paper_tissue185.jpg: 384x480 1 plastic, 5.3ms
# image 114/174 /content/data/validation/images/paper_tissue198.jpg: 384x480 1 plastic, 5.3ms
# image 115/174 /content/data/validation/images/paper_tissue30.jpg: 384x480 1 plastic, 5.5ms
# image 116/174 /content/data/validation/images/paper_tissue33.jpg: 384x480 1 plastic, 5.5ms
# image 117/174 /content/data/validation/images/paper_tissue36.jpg: 384x480 2 plastics, 5.4ms
# image 118/174 /content/data/validation/images/paper_tissue37.jpg: 384x480 1 plastic, 5.3ms
# image 119/174 /content/data/validation/images/paper_tissue56.jpg: 384x480 1 plastic, 5.3ms
# image 120/174 /content/data/validation/images/paper_tissue65.jpg: 384x480 1 plastic, 5.3ms
# image 121/174 /content/data/validation/images/paper_tissue86.jpg: 384x480 1 plastic, 5.3ms
# image 122/174 /content/data/validation/images/paper_tissue88.jpg: 384x480 1 plastic, 5.2ms
# image 123/174 /content/data/validation/images/paper_tissue96.jpg: 384x480 1 plastic, 5.2ms
# image 124/174 /content/data/validation/images/paper_tissue99.jpg: 384x480 1 plastic, 5.5ms
# image 125/174 /content/data/validation/images/plastic_bag116.jpg: 480x480 1 paper, 6.1ms
# image 126/174 /content/data/validation/images/plastic_bag119.jpg: 480x480 1 paper, 5.3ms
# image 127/174 /content/data/validation/images/plastic_bag184.jpg: 480x480 1 paper, 5.3ms
# image 128/174 /content/data/validation/images/plastic_bag197.jpg: 480x480 1 paper, 5.2ms
# image 129/174 /content/data/validation/images/plastic_bag21.jpg: 480x480 1 paper, 5.3ms
# image 130/174 /content/data/validation/images/plastic_bag38.jpg: 480x480 1 paper, 6.8ms
# image 131/174 /content/data/validation/images/plastic_bag54.jpg: 480x480 1 paper, 5.3ms
# image 132/174 /content/data/validation/images/plastic_bag61.jpg: 480x480 1 paper, 5.5ms
# image 133/174 /content/data/validation/images/plastic_bag64.jpg: 480x480 4 papers, 5.3ms
# image 134/174 /content/data/validation/images/plastic_bag68.jpg: 480x480 1 paper, 5.6ms
# image 135/174 /content/data/validation/images/plastic_bag81.jpg: 480x480 1 paper, 6.2ms
# image 136/174 /content/data/validation/images/plastic_bag96.jpg: 480x480 1 paper, 6.0ms
# image 137/174 /content/data/validation/images/plastic_bottle1.jpg: 480x480 1 paper, 5.9ms
# image 138/174 /content/data/validation/images/plastic_bottle103.jpg: 480x480 1 paper, 5.9ms
# image 139/174 /content/data/validation/images/plastic_bottle109.jpg: 480x480 1 paper, 6.0ms
# image 140/174 /content/data/validation/images/plastic_bottle116.jpg: 480x480 3 papers, 5.9ms
# image 141/174 /content/data/validation/images/plastic_bottle120.jpg: 480x480 2 papers, 6.0ms
# image 142/174 /content/data/validation/images/plastic_bottle124.jpg: 480x480 3 papers, 6.1ms
# image 143/174 /content/data/validation/images/plastic_bottle14.jpg: 480x480 1 paper, 6.2ms
# image 144/174 /content/data/validation/images/plastic_bottle142.jpg: 480x480 1 paper, 6.1ms
# image 145/174 /content/data/validation/images/plastic_bottle150.jpg: 480x480 1 paper, 6.2ms
# image 146/174 /content/data/validation/images/plastic_bottle175.jpg: 480x480 1 paper, 6.4ms
# image 147/174 /content/data/validation/images/plastic_bottle186.jpg: 480x480 1 paper, 6.2ms
# image 148/174 /content/data/validation/images/plastic_bottle191.jpg: 480x480 1 paper, 6.2ms
# image 149/174 /content/data/validation/images/plastic_bottle57.jpg: 480x480 1 paper, 6.2ms
# image 150/174 /content/data/validation/images/plastic_bottle60.jpg: 480x480 1 paper, 6.3ms
# image 151/174 /content/data/validation/images/plastic_bottle63.jpg: 480x480 1 paper, 7.1ms
# image 152/174 /content/data/validation/images/plastic_bottle71.jpg: 480x480 1 paper, 10.6ms
# image 153/174 /content/data/validation/images/plastic_bottle75.jpg: 480x480 1 paper, 9.7ms
# image 154/174 /content/data/validation/images/plastic_bottle87.jpg: 480x480 1 paper, 6.0ms
# image 155/174 /content/data/validation/images/plastic_bottle96.jpg: 480x480 4 papers, 1 plastic, 5.9ms
# image 156/174 /content/data/validation/images/plastic_straw109.jpg: 480x480 (no detections), 5.7ms
# image 157/174 /content/data/validation/images/plastic_straw119.jpg: 480x480 1 paper, 5.7ms
# image 158/174 /content/data/validation/images/plastic_straw120.jpg: 480x480 (no detections), 6.3ms
# image 159/174 /content/data/validation/images/plastic_straw128.jpg: 480x480 1 paper, 5.5ms
# image 160/174 /content/data/validation/images/plastic_straw138.jpg: 480x480 (no detections), 5.8ms
# image 161/174 /content/data/validation/images/plastic_straw144.jpg: 480x480 1 metal, 5.5ms
# image 162/174 /content/data/validation/images/plastic_straw16.jpg: 480x480 (no detections), 5.7ms
# image 163/174 /content/data/validation/images/plastic_straw161.jpg: 480x480 (no detections), 5.8ms
# image 164/174 /content/data/validation/images/plastic_straw175.jpg: 480x480 (no detections), 5.8ms
# image 165/174 /content/data/validation/images/plastic_straw200.jpg: 480x480 1 paper, 6.2ms
# image 166/174 /content/data/validation/images/plastic_straw3.jpg: 480x480 1 plastic, 6.1ms
# image 167/174 /content/data/validation/images/plastic_straw33.jpg: 480x480 2 papers, 5.8ms
# image 168/174 /content/data/validation/images/plastic_straw43.jpg: 480x480 1 paper, 5.8ms
# image 169/174 /content/data/validation/images/plastic_straw53.jpg: 480x480 (no detections), 5.4ms
# image 170/174 /content/data/validation/images/plastic_straw59.jpg: 480x480 (no detections), 5.4ms
# image 171/174 /content/data/validation/images/plastic_straw63.jpg: 480x480 (no detections), 5.6ms
# image 172/174 /content/data/validation/images/plastic_straw83.jpg: 480x480 1 paper, 5.4ms
# image 173/174 /content/data/validation/images/plastic_straw84.jpg: 480x480 1 paper, 5.3ms
# image 174/174 /content/data/validation/images/plastic_straw95.jpg: 480x480 (no detections), 5.3ms
# Speed: 1.4ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 480)
# Results saved to /content/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import glob
from IPython.display import Image, display
for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg')[:10]:
  display(Image(filename=image_path, height=400))
  print('\n')

# %% [markdown]
# The model should draw a box around each object of interest in each image. If it isn't doing a good job of detecting objects, here are a few tips:
#
# 1. Double-check your dataset to make sure there are no labeling errors or conflicting examples.
# 2. Increase the number of epochs used for training.
# 3. Use a larger model size (e.g. `yolo11l.pt`).
# 4. Add more images to the training dataset. See my [dataset video](https://www.youtube.com/watch?v=v0ssiOY6cfg) for tips on how to capture good training images and improve accuracy.
#
# You can also run the model on video files or other images images by uploading them to this notebook and using the above `!yolo detect predict` command, where `source` points to the location of the video file, image, or folder of images. The results will be saved in `runs/detect/predict`.
#
# Drawing boxes on images is great, but it isn't very useful in itself. It's also not very helpful to just run this models inside a Colab notebook: it's easier if we can just run it on a local computer. Continue to the next section to see how to download your newly trained model and run it on a local device.

# %% [markdown]
# #7.&nbsp;Deploy Model

# %% [markdown]
# Now that your custom model has been trained, it's ready to be downloaded and deployed in an application! YOLO models can run on a wide variety of hardware, including PCs, embedded systems, and phones. Ultralytics makes it easy to convert the YOLO models to various formats (`tflite`, `onnx`, etc.) and deploy them in a variety of environments.
#
# This section shows how to download the model and provides links to instructions for deploying it on your PC and edge devices like the Raspberry Pi.

# %% [markdown]
# ## 7.1 Download YOLO Model
#
# First, zip and download the trained model by running the code blocks below.
#
# The code creates a folder named `my_model`, moves the model weights into it, and renames them from `best.pt` to `my_model.pt`. It also adds the training results in case you want to reference them later. It then zips the folder as `my_model.zip`.

# %%
# Create "my_model" folder to store model weights and train results
# !mkdir /content/my_model
# !cp /content/runs/detect/train/weights/best.pt /content/my_model/my_model.pt
# !cp -r /content/runs/detect/train /content/my_model

# Zip into "my_model.zip"
# %cd my_model
# !zip /content/my_model.zip my_model.pt
# !zip -r /content/my_model.zip train
# %cd /content
# Out:
# /content/my_model
#   adding: my_model.pt (deflated 8%)
#   adding: train/ (stored 0%)
#   adding: train/results.csv (deflated 70%)
#   adding: train/val_batch2_labels.jpg (deflated 14%)
#   adding: train/confusion_matrix_normalized.png (deflated 27%)
#   adding: train/BoxP_curve.png (deflated 12%)
#   adding: train/val_batch1_pred.jpg (deflated 12%)
#   adding: train/BoxF1_curve.png (deflated 10%)
#   adding: train/confusion_matrix.png (deflated 32%)
#   adding: train/train_batch1.jpg (deflated 8%)
#   adding: train/train_batch1322.jpg (deflated 13%)
#   adding: train/train_batch1321.jpg (deflated 13%)
#   adding: train/results.png (deflated 7%)
#   adding: train/args.yaml (deflated 53%)
#   adding: train/labels.jpg (deflated 22%)
#   adding: train/train_batch2.jpg (deflated 8%)
#   adding: train/BoxR_curve.png (deflated 12%)
#   adding: train/train_batch1320.jpg (deflated 12%)
#   adding: train/val_batch0_pred.jpg (deflated 14%)
#   adding: train/BoxPR_curve.png (deflated 18%)
#   adding: train/val_batch1_labels.jpg (deflated 13%)
#   adding: train/train_batch0.jpg (deflated 7%)
#   adding: train/weights/ (stored 0%)
#   adding: train/weights/last.pt (deflated 8%)
#   adding: train/weights/best.pt (deflated 8%)
#   adding: train/val_batch0_labels.jpg (deflated 14%)
#   adding: train/val_batch2_pred.jpg (deflated 14%)
# /content

# %%
# This takes forever for some reason, you can also just download the model from the sidebar
from google.colab import files

files.download('/content/my_model.zip')

# %% [markdown]
# ## 7.2 Deploy YOLO Model on Local Devices
#
# Next, we'll take our downloaded model and run it on a local device. This section provides instructions showing how to deploy YOLO models on various devices.
#
# I wrote a basic Python script, `yolo_detect.py`, that shows how to load a model, run inference on an image source, parse the inference results, and display boxes around each detected class in the image. The [script](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/blob/main/yolo_detect.py) gives an example of how to work with Ultralytics YOLO models in Python, and it can be used as a starting point for more advanced applications.

# %% [markdown]
# ### 7.2.1 Deploy on PC (Windows, Linux, or macOS)
#
# The easiest way to run Ultralytics models on a PC is using Anaconda. Anaconda sets up a virtual Python environment and allows you to easily install Ultralytics and PyTorch. It automatically installs CUDA and cuDNN, which allows you to speed up model inference with your NVIDIA GPU.
#
# > **NOTE:** My YouTube video (link to be added) shows how to deploy your model on a PC. It walks through the following steps, so watch the video if you prefer having visual instructions.
#
# **1. Download and Install Anaconda**
#
# Go to the Anaconda download page at https://anaconda.com/download, click the “skip registration” button, and then download the package for your OS. When it's finished downloading, run the installer and click through the installation steps. You can use the default options for installation.
#
# **2. Set up virtual environment**
#
# Once it's installed, run Anaconda Prompt from the Start Bar. (If you're on macOS or Linux, just open a command terminal).
#
# Issue the following commands to create a new Python environment and activate it:
#
# ```
# conda create --name yolo-env1 python=3.12 -y
# conda activate yolo-env1
# ```
#
# Install Ultralytics (which also installs import libraries like OpenCV-Python, Numpy, and PyTorch) by issuing the following command:
#
# ```
# pip install ultralytics
# ```
#
# If you have an NVIDIA GPU, you can install the GPU-enabled version of PyTorch by issuing the following command:
#
# ```
# pip install --upgrade torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124
# ```
#
# **3. Extract downloaded model**
# Take the `my_model.zip` file you downloaded in Step 7.1 and unzip it to a folder on your PC. In the Anaconda Prompt terminal, move into the unzipped folder using:
#
# ```
# cd path/to/folder
# ```
#
# **4. Download and run yolo_detect.py**
#
# Download the `yolo_detect.py` script into the `my_model` folder using:
#
# ```
# curl -o yolo_detect.py https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/yolo_detect.py
# ```
#
# Alright! We're ready to run the script. To run inference with a yolov8s model on a USB camera at 1280x720 resolution, issue:
#
# ```
# python yolo_detect.py --model my_model.pt --source usb0 --resolution 1280x720
# ```
#
# A window will appear showing a live feed from your webcam with boxes drawn around detected objects in each frame.
#
# You can also run the model on an video file, image, or folder of images. To see a full list of arguments for `yolo_detect.py`, issue `python yolo_detect.py --help` or see the [README file](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/blob/main/README.md).

# %% [markdown]
# ### 7.2.2 Deploy on Raspberry Pi
#
# Keep an eye out for an article showing how to convert YOLO models to NCNN format and run them on the Raspberry Pi!

# %% [markdown]
# # 8.&nbsp;Conclusion

# %% [markdown]
# Congratulations! You've successfully trained and deployed a YOLO object detection model. 😀
#
# Next, you can extend your application beyond just drawing boxes and counting objects. Add functionality like logging the number of objects detected over time or taking a picture when certain objects are detected. Check out some example applications at our GitHub repository: https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models
#
# Thanks for working through this notebook, and good luck with your projects!

# %% [markdown]
# # Appendix: Common Errors

# %% [markdown]
# If you run into any errors working through this notebook, please do the following:
#
#
# - Double-check that the dataset files are set up in the correct folder structure
# - Make sure there are no typos or errors in your labelmap file
# - Google search the error to look for solutions
#
# If none of those help, please submit an [Issue](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/issues) on the GitHub page. In this section, I will add resolutions to common errors as they come up.
